# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
train = 'train1.csv'

df = pd.read_csv(train, sep=';')
# %matplotlib inline

# %%
df.head()
# Out:
#     NISN  Nama   Umur   Kelas  Rerata UN  Rata­rata Nilai Sekolah      Hasil
# 0  27786  Akbar     17  IPA 1         87                       83      Lolos
# 1  38539  Opang     17  IPA 2         83                       91      Lolos
# 2  47031  Erwan     18  IPA 2         91                       84      Lolos
# 3  58624   Kaka     17  IPS 3         90                      100      Lolos
# 4  68091   Cimo     17  IPS 4         82                       75  Coba lagi

# %%
df.describe()
# Out:
#                NISN      Umur   Rerata UN  Rata­rata Nilai Sekolah
# count     28.000000  28.000000  28.000000                  28.0000
# mean   56611.464286  16.964286  85.285714                  83.7500
# std    26710.246836   0.744468   5.563486                   8.4091
# min    17189.000000  16.000000  78.000000                  71.0000
# 25%    34705.500000  16.000000  80.000000                  77.0000
# 50%    57623.000000  17.000000  83.000000                  84.0000
# 75%    78098.750000  17.250000  91.000000                  91.0000
# max    98472.000000  18.000000  95.000000                 100.0000

# %%
# library & dataset
import seaborn as sns
import matplotlib.pyplot as plt
 
# Basic correlogram
sns.pairplot(df, kind='scatter')
plt.show()

# %%
df
# Out:
#      NISN     Nama   Umur      Kelas  Rerata UN  Rata­rata Nilai Sekolah  \
# 0   27786     Akbar     17     IPA 1         87                       83
# 1   38539     Opang     17     IPA 2         83                       91
# 2   47031     Erwan     18     IPA 2         91                       84
# 3   58624      Kaka     17     IPS 3         90                      100
# 4   68091      Cimo     17     IPS 4         82                       75
# 5   77820      Ejak     17     IPS 6         80                       78
# 6   87883      Hoho     16     IPS 2         78                       77
# 7   98472     Perdo     17     IPS 1         81                       72
# 8   17303      Raka     16     IPS 4         82                       72
# 9   27392      Tomo     18     IPA 4         80                       84
# 10  38806      Audi     17  Bahasa 1         79                       91
# 11  48462     Cakra     16     IPS 3         91                       79
# ...

# %%
sns.pairplot(df, kind="scatter", hue="Hasil", markers=["o", "s"], palette="Set2")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
array = df.values

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
col_names = ['nisn', 'nama', 'umur','kelas', 'rata-un','rata-sekolah', 'hasil']
# load dataset
pima = pd.read_csv("train1.csv", sep=';')

# %%
pima.head()
# Out:
#     NISN  Nama   Umur   Kelas  Rerata UN  Rata­rata Nilai Sekolah      Hasil
# 0  27786  Akbar     17  IPA 1         87                       83      Lolos
# 1  38539  Opang     17  IPA 2         83                       91      Lolos
# 2  47031  Erwan     18  IPA 2         91                       84      Lolos
# 3  58624   Kaka     17  IPS 3         90                      100      Lolos
# 4  68091   Cimo     17  IPS 4         82                       75  Coba lagi

# %%
pima.columns = ['nisn', 'nama', 'umur','kelas', 'rata-un','rata-sekolah', 'hasil']

# %%
pima
# Out:
#      nisn      nama  umur     kelas  rata-un  rata-sekolah      hasil
# 0   27786     Akbar    17     IPA 1       87            83      Lolos
# 1   38539     Opang    17     IPA 2       83            91      Lolos
# 2   47031     Erwan    18     IPA 2       91            84      Lolos
# 3   58624      Kaka    17     IPS 3       90           100      Lolos
# 4   68091      Cimo    17     IPS 4       82            75  Coba lagi
# 5   77820      Ejak    17     IPS 6       80            78  Coba lagi
# 6   87883      Hoho    16     IPS 2       78            77  Coba lagi
# 7   98472     Perdo    17     IPS 1       81            72  Coba lagi
# 8   17303      Raka    16     IPS 4       82            72  Coba lagi
# 9   27392      Tomo    18     IPA 4       80            84      Lolos
# 10  38806      Audi    17  Bahasa 1       79            91      Lolos
# 11  48462     Cakra    16     IPS 3       91            79      Lolos
# ...

# %%
pimatest = pd.read_csv("test1.csv", sep=';')

pimatest
# Out:
#      NISN    Nama   Umur   Kelas  Rerata UN  Rerata Nilai Sekolah Hasil
# 0   12345     Risa     16  IPA 1         80                    94    ?
# 1   56789    Putri     18  IPS 2         70                    97    ?
# 2   12452     Aris     17  IPA 3         84                    77    ?
# 3   24566      Ida     17  IPA 2         90                    89    ?
# 4   78657     Tuti     17  IPS 4         92                    92    ?
# 5   28428  Nugraha     16  IPA 1         93                    81    ?
# 6   93020      Adi     18  IPA 2         91                    92    ?
# 7   24748     Sora     16  IPA 6         79                    78    ?
# 8   85326      Eka     18  IPA 2         87                    78    ?
# 9   37944    Ahmad     16  IPS 1         88                    95    ?
# 10  27424    Andre     18  IPS 2         89                    83     ?

# %%
sns.pairplot(pimatest,kind="reg")
plt.show()

# %%
pimatest.columns = ['nisn', 'nama', 'umur','kelas', 'rata-un','rata-sekolah', 'hasil']

# %%
# feature_cols = ['rata-un','rata-sekolah']
X = pima[feature_cols] # Features
y = pima.hasil # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array(['Coba lagi', 'Lolos', 'Lolos', 'Coba lagi', 'Coba lagi', 'Lolos',
#        'Lolos', 'Lolos', 'Lolos'], dtype=object)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8888888888888888

# %%
X_real = pimatest[feature_cols] #features
y_real = pimatest.hasil
y_realpred = clf.predict(X_real)
print(y_realpred)
# Out:
# ['Lolos' 'Lolos' 'Coba lagi' 'Lolos' 'Lolos' 'Lolos' 'Lolos' 'Coba lagi'
#  'Coba lagi' 'Lolos' 'Lolos']

# %%
for y in y_realpred:
    i = 0
    pimatest['hasil'][i] = y
    i=i+1
pimatest.head()
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     nisn   nama  umur  kelas  rata-un  rata-sekolah  hasil
# 0  Lolos   Risa    16  IPA 1       80            94  Lolos
# 1  56789  Putri    18  IPS 2       70            97     ?
# 2  12452   Aris    17  IPA 3       84            77     ?
# 3  24566    Ida    17  IPA 2       90            89     ?
# 4  78657   Tuti    17  IPS 4       92            92     ?

# %%
y_realpred[1]
# Out:
# 'Lolos'

# %%
for i in range(len(pimatest)):
     pimatest['hasil'][i] = y_realpred[i]
pimatest
# Out:
# /miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      nisn     nama  umur  kelas  rata-un  rata-sekolah      hasil
# 0   Lolos     Risa    16  IPA 1       80            94      Lolos
# 1   56789    Putri    18  IPS 2       70            97      Lolos
# 2   12452     Aris    17  IPA 3       84            77  Coba lagi
# 3   24566      Ida    17  IPA 2       90            89      Lolos
# 4   78657     Tuti    17  IPS 4       92            92      Lolos
# 5   28428  Nugraha    16  IPA 1       93            81      Lolos
# 6   93020      Adi    18  IPA 2       91            92      Lolos
# 7   24748     Sora    16  IPA 6       79            78  Coba lagi
# 8   85326      Eka    18  IPA 2       87            78  Coba lagi
# ...

# %%
# instantiate the regressor class
regressor = LinearRegression()

# fit the build the model by fitting the regressor to the training data
regressor.fit(X_train, y_train)

# make a prediction set using the test set
prediction = regressor.predict(X_test)

# Evaluate the prediction accuracy of the model
from sklearn.metrics import mean_absolute_error, median_absolute_error
print("The Explained Variance: %.2f" % regressor.score(X_test, y_test))
print("The Mean Absolute Error: %.2f degrees celsius" % mean_absolute_error(y_test, prediction))
print("The Median Absolute Error: %.2f degrees celsius" % median_absolute_error(y_test, prediction))
